# %%
pip install deepface
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.6/63.6 KB 247.8 kB/s eta 0:00:00 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 5.6 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.2/95.2 KB 501.8 kB/s eta 0:00:00a 0:00:01
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.4/96.4 KB 651.4 kB/s eta 0:00:00a 0:00:01
# ...
#   Created wheel for gdown: filename=gdown-4.4.0-py3-none-any.whl size=14775 sha256=05bb56e157975f0093daaf5694070e8489ea79e48f51176c93219d7d3bc4420d
#   Stored in directory: /Users/admin/Library/Caches/pip/wheels/03/0b/3f/6ddf67a417a5b400b213b0bb772a50276c199a386b12c06bfc
# Successfully built gdown
# ...
#   WARNING: The script flask is installed in '/Library/Frameworks/Python.framework/Versions/3.10/bin' which is not on PATH.
# ...

# %%
from deepface import DeepFace
import cv2
import matplotlib.pyplot as plt

img1_path ='akash/akash7.jpg'
img2_path = 'viswa/viswa1.jpg'
img1 = cv2.imread(img1_path)
img2 = cv2.imread(img2_path)
plt.imshow(img1[:,:,::-1])
plt.show()
plt.imshow(img2[:,:,::-1])
plt.show()
result = DeepFace.verify(img1_path ,img2_path ,model_name="Facenet512")
result
# Out:
# {'verified': False,
#  'distance': 0.3007761354444919,
#  'threshold': 0.3,
#  'model': 'Facenet512',
#  'detector_backend': 'opencv',
#  'similarity_metric': 'cosine'}

# %%
from deepface import DeepFace
import cv2
import matplotlib.pyplot as plt

img1_path ='viswa/viswa3.jpg'
img2_path = 'viswa/viswa1.jpg'
img1 = cv2.imread(img1_path)
img2 = cv2.imread(img2_path)
plt.imshow(img1[:,:,::-1])
plt.show()
plt.imshow(img2[:,:,::-1])
plt.show()
result = DeepFace.verify(img1_path ,img2_path ,model_name="Facenet512")
result
# Out:
# {'verified': True,
#  'distance': 0.03399438275738187,
#  'threshold': 0.3,
#  'model': 'Facenet512',
#  'detector_backend': 'opencv',
#  'similarity_metric': 'cosine'}

# %%
from deepface import DeepFace
DeepFace.stream(db_path = "/Users/admin/Documents/deep_face/",model_name="Facenet512")
# Out:
# Detector backend is  opencv
# Facenet512  is built
# Emotion model loaded
# Age model loaded
# Gender model loaded
# Facial attibute analysis models loaded in  20.245205879211426  seconds
# Finding embedding for viswa1.jpg: 100%|██████████| 24/24 [00:30<00:00,  1.29s/it]
# Embeddings found for given data set in  33.07391381263733  seconds
